# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import numpy as np

# %%
# simple data

x=np.arange(0,10)
y=np.arange(11,21)

a=np.arange(21,30)
b=np.arange(40,50)

# %%
plt.scatter(x,y,color='g')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('sample')
# Out:
# Text(0.5, 1.0, 'sample')

# %%
plt.plot(x,y,'ro',linestyle='dashed')

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*--')
plt.subplot(2,2,3)
plt.plot(x,y,'bo')
plt.subplot(2,2,4)
plt.plot(x,y,'go')

# %%
x= np.arange(0,8*np.pi,0.02)
y = np.sin(x)

plt.plot(x,y)
